# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import cv2
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import numpy as np
import os
from PIL import Image, ExifTags

# %%
MARGIN = 10
FONT_SIZE = 1
FONT_THICKNESS = 1
HANDEDNESS_TEXT_COLOR = (88, 205, 54)

#By nie obracało obrazu - Poprawne załadowanie zdjęcia z uwzględnieniem jego obrotu zapisanego w danych EXIF
def load_image_correct_orientation(path):
    image = Image.open(path)
    try:
        for orientation in ExifTags.TAGS: #orientation określa w jaki sposób aparat "obracał" zdjęcie
            if ExifTags.TAGS[orientation] == 'Orientation':
                break
        exif = image._getexif()
        if exif is not None: #jeśli istnieje
            orientation_value = exif.get(orientation, None)
            if orientation_value == 3: #obrócone o 180
                image = image.rotate(180, expand=True) #obraca odpowiednio obraz
            elif orientation_value == 6: #obrócone o 270
                image = image.rotate(270, expand=True)
            elif orientation_value == 8: #obrócone o 90
                image = image.rotate(90, expand=True)
    except Exception:
        pass
    return np.array(image.convert("RGB")) #Konwertuje obraz do RGB i zwraca jako tablicę NumPy

#rysuje landmarki i wektory dłoni na obrazie
def draw_landmarks_on_image(rgb_image, detection_result):
    annotated_image = np.copy(rgb_image)
    for idx, hand_landmarks in enumerate(detection_result.hand_landmarks):
        handedness = detection_result.handedness[idx]

        hand_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        hand_landmarks_proto.landmark.extend([
            landmark_pb2.NormalizedLandmark(x=lm.x, y=lm.y, z=lm.z) for lm in hand_landmarks
        ])

        solutions.drawing_utils.draw_landmarks(
            annotated_image,
            hand_landmarks_proto,
            solutions.hands.HAND_CONNECTIONS,
            solutions.drawing_styles.get_default_hand_landmarks_style(),
            solutions.drawing_styles.get_default_hand_connections_style()
        )

        height, width, _ = annotated_image.shape
        x_coords = [lm.x for lm in hand_landmarks]
        y_coords = [lm.y for lm in hand_landmarks]
        text_x = int(min(x_coords) * width)
        text_y = int(min(y_coords) * height) - MARGIN

        cv2.putText(annotated_image, f"{handedness[0].category_name}",
                    (text_x, text_y), cv2.FONT_HERSHEY_DUPLEX,
                    FONT_SIZE, HANDEDNESS_TEXT_COLOR, FONT_THICKNESS, cv2.LINE_AA)

    return annotated_image

#oblicza wektory
def calculate_vectors(hand_landmarks):
    vectors = []
    for connection in solutions.hands.HAND_CONNECTIONS:
        start_idx, end_idx = connection
        p1 = hand_landmarks[start_idx]
        p2 = hand_landmarks[end_idx]
        vector = (p2.x - p1.x, p2.y - p1.y, p2.z - p1.z)
        vectors.append((start_idx, end_idx, vector))
    return vectors



#Do formatowania wyników detekcji dłoni(czytelny zapis w txt)
def format_detection_data(detection_result, is_flipped=False):
    lines = [] # lista stringów
    #Przejście po każdej wykrytej dłoni
    for idx, hand_landmarks in enumerate(detection_result.hand_landmarks):
        handedness = detection_result.handedness[idx][0].category_name
        flip_note = " (flipped)" if is_flipped else ""
        lines.append(f"Dłoń {idx + 1} ({handedness}{flip_note}):")
        for i, lm in enumerate(hand_landmarks):
            lines.append(f"  Punkt {i}: x={lm.x:.3f}, y={lm.y:.3f}, z={lm.z:.3f}")
        lines.append("  Wektory:")
        for start_idx, end_idx, vector in calculate_vectors(hand_landmarks):
            vx, vy, vz = vector
            lines.append(f"    {start_idx}→{end_idx}: ({vx:.3f}, {vy:.3f}, {vz:.3f})")
        lines.append("")  # pusta linia między dłońmi
    return lines

#Przetwarzanie obrazów dla jednego ze znaku, zapisuje wyniki detekcji do pliku tekstowego
def process_and_label_images_for_sign(sign_label, input_dir, output_dir, detector):
    # Nowy folder wyjściowy na dane
    os.makedirs(output_dir, exist_ok=True)

    # Lista plików .jpg w katalogu
    image_files = [f for f in os.listdir(input_dir) if f.lower().endswith('.jpg')]
    if not image_files:
        print(f"{sign_label}: Brak obrazów do przetworzenia.") #czy pusty
        return

    all_lines = []
    #przechodzi przez każdy obraz w katalogu input_dir
    for img_name in image_files:
        input_path = os.path.join(input_dir, img_name)
        base_filename = os.path.splitext(img_name)[0] #nazwa pliku bez rozszerzenia

        #Ładowanie i wykrywanie obrazu danego znaku.
        image = mp.Image.create_from_file(input_path)
        detection_result = detector.detect(image)

        if detection_result.hand_landmarks:
            all_lines.append(f"==== {base_filename} ====")
            all_lines.extend(format_detection_data(detection_result, is_flipped=False))

            # Flip (odbicie lustrzane)
            #flipped_np = cv2.flip(image.numpy_view(), 1)
            #flipped_mp = mp.Image(image_format=mp.ImageFormat.SRGB, data=flipped_np)
            #flipped_result = detector.detect(flipped_mp)

            #if flipped_result.hand_landmarks:
              #  all_lines.append(f"==== {base_filename}_flipped ====")
               # all_lines.extend(format_detection_data(flipped_result, is_flipped=True))

            print(f"{img_name}: dane dodane.")
        else:
            print(f"{img_name}: NIE wykryto dłoni")

    # Jeśli mamy dane, zapisujemy je do jednego pliku na symbol
    if all_lines:
        # Tworzy pełną ścieżkę do pliku wyjściowego
        output_path = os.path.join(output_dir, f"{sign_label}.txt")
        #otwiera plik to zapisu
        with open(output_path, "w", encoding="utf-8") as f:
            #zapisuje całe zebrane wczesniej dane
            f.write("\n".join(all_lines))
    else:
        #Usuwa folder wyjściowy, ponieważ jest pusty
        os.rmdir(output_dir)

#przechodzi przez wszystkie foldery w katalogu wejściowym (np. „a”, „b”, „a+” itd.)
def process_full_dataset(base_input_dir, base_output_dir, detector):

    for symbol_name in os.listdir(base_input_dir):
        input_dir = os.path.join(base_input_dir, symbol_name)
        if os.path.isdir(input_dir): #Sprawdzanie, czy element jest katalogiem
            print(f" Przetwarzanie symbolu: {symbol_name}")

            # Folder wyjściowy dla danego symbolu
            output_dir = os.path.join(base_output_dir, symbol_name)

            # Przetwarza obrazy dla danego znaku
            process_and_label_images_for_sign(symbol_name, input_dir, output_dir, detector)

#przetwarza wszystkie zdjęcia z datasetu (tworzy obrazy z landmarkami i wektorami i zapisuje je do folderu)
def detection_all_images_from_folder(input_base="Dataset Migowy PJM", output_base="outputImages"):

    base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
    options = vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
    detector = vision.HandLandmarker.create_from_options(options)

    os.makedirs(output_base, exist_ok=True)

    for label_folder in os.listdir(input_base):
        input_folder = os.path.join(input_base, label_folder)
        if not os.path.isdir(input_folder):
            continue

        output_folder = os.path.join(output_base, label_folder)
        os.makedirs(output_folder, exist_ok=True)

        for img_file in os.listdir(input_folder):
            if not img_file.lower().endswith((".jpg")):
                continue

            input_path = os.path.join(input_folder, img_file)
            output_name = os.path.splitext(img_file)[0]
            output_base_path = os.path.join(output_folder, output_name)

            # Wczytaj obraz z korektą orientacji
            img_np = load_image_correct_orientation(input_path)
            image = mp.Image(image_format=mp.ImageFormat.SRGB, data=img_np)
            detection_result = detector.detect(image)

            if detection_result.hand_landmarks:
                annotated = draw_landmarks_on_image(image.numpy_view(), detection_result)

                # Zapis obrazu i danych
                cv2.imwrite(f"{output_base_path}_annotated.jpg", cv2.cvtColor(annotated, cv2.COLOR_RGB2BGR))

                print(f"{img_file}: WYKRYTO dłonie i zapisano dane.")
            else:
                print(f"{img_file}: Brak wykrycia dłoni.")

#pobieranie wektorow i landmarkow do txt
def generate_hand_landmark_data(input_base = "PJM", output_base = "outputdetection_data"):

    base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
    options = vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
    detector = vision.HandLandmarker.create_from_options(options)

    # Przetwarzanie całego datasetu
    process_full_dataset(input_base, output_base, detector)

#detection_all_images_from_folder()
generate_hand_landmark_data()
# Out:
#  Przetwarzanie symbolu: a+_images
# a+_000001_1_frame1.jpg: dane dodane.
# a+_000001_1_frame10.jpg: dane dodane.
# a+_000001_1_frame2.jpg: dane dodane.
# a+_000001_1_frame3.jpg: dane dodane.
# a+_000001_1_frame4.jpg: dane dodane.
# a+_000001_1_frame5.jpg: dane dodane.
# a+_000001_1_frame6.jpg: dane dodane.
# a+_000001_1_frame7.jpg: dane dodane.
# a+_000001_1_frame8.jpg: dane dodane.
# a+_000001_1_frame9.jpg: dane dodane.
# a+_000002_1_frame1.jpg: dane dodane.
# a+_000002_1_frame10.jpg: dane dodane.
# a+_000002_1_frame2.jpg: dane dodane.
# a+_000002_1_frame3.jpg: dane dodane.
# a+_000002_1_frame4.jpg: dane dodane.
# a+_000002_1_frame5.jpg: NIE wykryto dłoni
# a+_000002_1_frame6.jpg: NIE wykryto dłoni
# a+_000002_1_frame7.jpg: dane dodane.
# a+_000002_1_frame8.jpg: dane dodane.
# a+_000002_1_frame9.jpg: dane dodane.
# a+_000003_1_frame1.jpg: dane dodane.
# a+_000003_1_frame10.jpg: dane dodane.
# a+_000003_1_frame2.jpg: dane dodane.
# a+_000003_1_frame3.jpg: dane dodane.
# a+_000003_1_frame4.jpg: dane dodane.
# a+_000003_1_frame5.jpg: dane dodane.
# a+_000003_1_frame6.jpg: dane dodane.
# a+_000003_1_frame7.jpg: dane dodane.
# a+_000003_1_frame8.jpg: dane dodane.
# a+_000003_1_frame9.jpg: dane dodane.
# a+_000003_3_frame1.jpg: dane dodane.
# a+_000003_3_frame10.jpg: dane dodane.
# a+_000003_3_frame2.jpg: dane dodane.
# a+_000003_3_frame3.jpg: dane dodane.
# a+_000003_3_frame4.jpg: dane dodane.
# a+_000003_3_frame5.jpg: dane dodane.
# a+_000003_3_frame6.jpg: dane dodane.
# a+_000003_3_frame7.jpg: dane dodane.
# a+_000003_3_frame8.jpg: dane dodane.
# a+_000003_3_frame9.jpg: dane dodane.
# a+_000004_1_frame1.jpg: dane dodane.
# a+_000004_1_frame10.jpg: dane dodane.
# a+_000004_1_frame2.jpg: dane dodane.
# a+_000004_1_frame3.jpg: dane dodane.
# a+_000004_1_frame4.jpg: dane dodane.
# a+_000004_1_frame5.jpg: dane dodane.
# a+_000004_1_frame6.jpg: dane dodane.
# a+_000004_1_frame7.jpg: dane dodane.
# a+_000004_1_frame8.jpg: dane dodane.
# a+_000004_1_frame9.jpg: dane dodane.
# a+_000004_3_frame1.jpg: dane dodane.
# a+_000004_3_frame10.jpg: dane dodane.
# a+_000004_3_frame2.jpg: dane dodane.
# a+_000004_3_frame3.jpg: dane dodane.
# a+_000004_3_frame4.jpg: dane dodane.
# a+_000004_3_frame5.jpg: dane dodane.
# a+_000004_3_frame6.jpg: dane dodane.
# a+_000004_3_frame7.jpg: dane dodane.
# a+_000004_3_frame8.jpg: dane dodane.
# a+_000004_3_frame9.jpg: dane dodane.
# a+_000005_3_frame1.jpg: NIE wykryto dłoni
# a+_000005_3_frame10.jpg: NIE wykryto dłoni
# a+_000005_3_frame2.jpg: dane dodane.
# a+_000005_3_frame3.jpg: dane dodane.
# a+_000005_3_frame4.jpg: dane dodane.
# a+_000005_3_frame5.jpg: NIE wykryto dłoni
# a+_000005_3_frame6.jpg: dane dodane.
# a+_000005_3_frame7.jpg: NIE wykryto dłoni
# a+_000005_3_frame8.jpg: NIE wykryto dłoni
# a+_000005_3_frame9.jpg: dane dodane.
# a+_000006_1_frame1.jpg: dane dodane.
# a+_000006_1_frame10.jpg: dane dodane.
# a+_000006_1_frame2.jpg: dane dodane.
# a+_000006_1_frame3.jpg: dane dodane.
# a+_000006_1_frame4.jpg: dane dodane.
# a+_000006_1_frame5.jpg: dane dodane.
# a+_000006_1_frame6.jpg: dane dodane.
# a+_000006_1_frame7.jpg: dane dodane.
# a+_000006_1_frame8.jpg: dane dodane.
# a+_000006_1_frame9.jpg: dane dodane.
# a+_000006_2_frame1.jpg: dane dodane.
# a+_000006_2_frame10.jpg: dane dodane.
# a+_000006_2_frame2.jpg: dane dodane.
# a+_000006_2_frame3.jpg: dane dodane.
# a+_000006_2_frame4.jpg: dane dodane.
# a+_000006_2_frame5.jpg: dane dodane.
# a+_000006_2_frame6.jpg: dane dodane.
# a+_000006_2_frame7.jpg: dane dodane.
# a+_000006_2_frame8.jpg: dane dodane.
# a+_000006_2_frame9.jpg: dane dodane.
# a+_000006_3_frame1.jpg: dane dodane.
# a+_000006_3_frame10.jpg: dane dodane.
# a+_000006_3_frame2.jpg: dane dodane.
# a+_000006_3_frame3.jpg: dane dodane.
# a+_000006_3_frame4.jpg: dane dodane.
# a+_000006_3_frame5.jpg: dane dodane.
# a+_000006_3_frame6.jpg: dane dodane.
# a+_000006_3_frame7.jpg: dane dodane.
# a+_000006_3_frame8.jpg: dane dodane.
# a+_000006_3_frame9.jpg: dane dodane.
# a+_000007_1_frame1.jpg: dane dodane.
# a+_000007_1_frame10.jpg: dane dodane.
# a+_000007_1_frame2.jpg: dane dodane.
# a+_000007_1_frame3.jpg: dane dodane.
# a+_000007_1_frame4.jpg: dane dodane.
# a+_000007_1_frame5.jpg: dane dodane.
# a+_000007_1_frame6.jpg: dane dodane.
# a+_000007_1_frame7.jpg: dane dodane.
# a+_000007_1_frame8.jpg: dane dodane.
# a+_000007_1_frame9.jpg: dane dodane.
# a+_000007_2_frame1.jpg: dane dodane.
# a+_000007_2_frame10.jpg: dane dodane.
# a+_000007_2_frame2.jpg: dane dodane.
# a+_000007_2_frame3.jpg: dane dodane.
# a+_000007_2_frame4.jpg: dane dodane.
# a+_000007_2_frame5.jpg: dane dodane.
# a+_000007_2_frame6.jpg: dane dodane.
# a+_000007_2_frame7.jpg: dane dodane.
# a+_000007_2_frame8.jpg: dane dodane.
# a+_000007_2_frame9.jpg: dane dodane.
# a+_000007_3_frame1.jpg: dane dodane.
# a+_000007_3_frame10.jpg: dane dodane.
# a+_000007_3_frame2.jpg: dane dodane.
# a+_000007_3_frame3.jpg: dane dodane.
# a+_000007_3_frame4.jpg: dane dodane.
# a+_000007_3_frame5.jpg: dane dodane.
# a+_000007_3_frame6.jpg: dane dodane.
# a+_000007_3_frame7.jpg: dane dodane.
# a+_000007_3_frame8.jpg: dane dodane.
# a+_000007_3_frame9.jpg: dane dodane.
# a+_000008_1_frame1.jpg: dane dodane.
# a+_000008_1_frame10.jpg: dane dodane.
# a+_000008_1_frame2.jpg: dane dodane.
# a+_000008_1_frame3.jpg: dane dodane.
# a+_000008_1_frame4.jpg: dane dodane.
# a+_000008_1_frame5.jpg: dane dodane.
# a+_000008_1_frame6.jpg: dane dodane.
# a+_000008_1_frame7.jpg: dane dodane.
# a+_000008_1_frame8.jpg: NIE wykryto dłoni
# a+_000008_1_frame9.jpg: dane dodane.
# a+_000008_2_frame1.jpg: dane dodane.
# a+_000008_2_frame10.jpg: dane dodane.
# a+_000008_2_frame2.jpg: dane dodane.
# a+_000008_2_frame3.jpg: dane dodane.
# a+_000008_2_frame4.jpg: dane dodane.
# a+_000008_2_frame5.jpg: dane dodane.
# a+_000008_2_frame6.jpg: dane dodane.
# a+_000008_2_frame7.jpg: dane dodane.
# a+_000008_2_frame8.jpg: dane dodane.
# a+_000008_2_frame9.jpg: dane dodane.
# a+_000008_3_frame1.jpg: dane dodane.
# a+_000008_3_frame10.jpg: dane dodane.
# a+_000008_3_frame2.jpg: dane dodane.
# a+_000008_3_frame3.jpg: dane dodane.
# a+_000008_3_frame4.jpg: dane dodane.
# a+_000008_3_frame5.jpg: dane dodane.
# a+_000008_3_frame6.jpg: NIE wykryto dłoni
# a+_000008_3_frame7.jpg: dane dodane.
# a+_000008_3_frame8.jpg: NIE wykryto dłoni
# a+_000008_3_frame9.jpg: dane dodane.
# a+_000009_1_frame1.jpg: dane dodane.
# a+_000009_1_frame10.jpg: dane dodane.
# a+_000009_1_frame2.jpg: dane dodane.
# a+_000009_1_frame3.jpg: dane dodane.
# a+_000009_1_frame4.jpg: dane dodane.
# a+_000009_1_frame5.jpg: dane dodane.
# a+_000009_1_frame6.jpg: dane dodane.
# a+_000009_1_frame7.jpg: dane dodane.
# a+_000009_1_frame8.jpg: dane dodane.
# a+_000009_1_frame9.jpg: dane dodane.
# a+_000009_2_frame1.jpg: dane dodane.
# a+_000009_2_frame10.jpg: dane dodane.
# a+_000009_2_frame2.jpg: dane dodane.
# a+_000009_2_frame3.jpg: dane dodane.
# a+_000009_2_frame4.jpg: dane dodane.
# a+_000009_2_frame5.jpg: dane dodane.
# a+_000009_2_frame6.jpg: dane dodane.
# a+_000009_2_frame7.jpg: dane dodane.
# a+_000009_2_frame8.jpg: dane dodane.
# a+_000009_2_frame9.jpg: dane dodane.
# a+_000010_1_frame1.jpg: dane dodane.
# a+_000010_1_frame10.jpg: dane dodane.
# a+_000010_1_frame2.jpg: dane dodane.
# a+_000010_1_frame3.jpg: dane dodane.
# a+_000010_1_frame4.jpg: dane dodane.
# a+_000010_1_frame5.jpg: dane dodane.
# a+_000010_1_frame6.jpg: dane dodane.
# a+_000010_1_frame7.jpg: dane dodane.
# a+_000010_1_frame8.jpg: dane dodane.
# a+_000010_1_frame9.jpg: dane dodane.
# a+_000010_2_frame1.jpg: dane dodane.
# a+_000010_2_frame10.jpg: dane dodane.
# a+_000010_2_frame2.jpg: dane dodane.
# a+_000010_2_frame3.jpg: dane dodane.
# a+_000010_2_frame4.jpg: dane dodane.
# a+_000010_2_frame5.jpg: dane dodane.
# a+_000010_2_frame6.jpg: dane dodane.
# a+_000010_2_frame7.jpg: dane dodane.
# a+_000010_2_frame8.jpg: dane dodane.
# a+_000010_2_frame9.jpg: dane dodane.
# a+_000011_1_frame1.jpg: dane dodane.
# a+_000011_1_frame10.jpg: dane dodane.
# a+_000011_1_frame2.jpg: dane dodane.
# a+_000011_1_frame3.jpg: dane dodane.
# a+_000011_1_frame4.jpg: dane dodane.
# a+_000011_1_frame5.jpg: dane dodane.
# a+_000011_1_frame6.jpg: dane dodane.
# a+_000011_1_frame7.jpg: dane dodane.
# a+_000011_1_frame8.jpg: dane dodane.
# a+_000011_1_frame9.jpg: dane dodane.
# a+_000011_2_frame1.jpg: dane dodane.
# a+_000011_2_frame10.jpg: dane dodane.
# a+_000011_2_frame2.jpg: dane dodane.
# a+_000011_2_frame3.jpg: dane dodane.
# a+_000011_2_frame4.jpg: dane dodane.
# a+_000011_2_frame5.jpg: dane dodane.
# a+_000011_2_frame6.jpg: dane dodane.
# a+_000011_2_frame7.jpg: dane dodane.
# a+_000011_2_frame8.jpg: dane dodane.
# a+_000011_2_frame9.jpg: dane dodane.
# a+_000012_1_frame1.jpg: dane dodane.
# a+_000012_1_frame10.jpg: dane dodane.
# a+_000012_1_frame2.jpg: dane dodane.
# a+_000012_1_frame3.jpg: dane dodane.
# a+_000012_1_frame4.jpg: dane dodane.
# a+_000012_1_frame5.jpg: dane dodane.
# a+_000012_1_frame6.jpg: dane dodane.
# a+_000012_1_frame7.jpg: dane dodane.
# a+_000012_1_frame8.jpg: dane dodane.
# a+_000012_1_frame9.jpg: dane dodane.
# a+_000012_2_frame1.jpg: dane dodane.
# a+_000012_2_frame10.jpg: dane dodane.
# a+_000012_2_frame2.jpg: dane dodane.
# a+_000012_2_frame3.jpg: dane dodane.
# a+_000012_2_frame4.jpg: NIE wykryto dłoni
# a+_000012_2_frame5.jpg: dane dodane.
# a+_000012_2_frame6.jpg: NIE wykryto dłoni
# a+_000012_2_frame7.jpg: NIE wykryto dłoni
# a+_000012_2_frame8.jpg: NIE wykryto dłoni
# a+_000012_2_frame9.jpg: dane dodane.
# a+_000013_1_frame1.jpg: dane dodane.
# a+_000013_1_frame10.jpg: dane dodane.
# a+_000013_1_frame2.jpg: dane dodane.
# a+_000013_1_frame3.jpg: dane dodane.
# a+_000013_1_frame4.jpg: dane dodane.
# a+_000013_1_frame5.jpg: dane dodane.
# a+_000013_1_frame6.jpg: dane dodane.
# a+_000013_1_frame7.jpg: dane dodane.
# a+_000013_1_frame8.jpg: dane dodane.
# a+_000013_1_frame9.jpg: dane dodane.
# a+_000013_2_frame1.jpg: dane dodane.
# a+_000013_2_frame10.jpg: dane dodane.
# a+_000013_2_frame2.jpg: dane dodane.
# a+_000013_2_frame3.jpg: dane dodane.
# a+_000013_2_frame4.jpg: dane dodane.
# a+_000013_2_frame5.jpg: dane dodane.
# a+_000013_2_frame6.jpg: dane dodane.
# a+_000013_2_frame7.jpg: dane dodane.
# a+_000013_2_frame8.jpg: dane dodane.
# a+_000013_2_frame9.jpg: dane dodane.
# a+_000014_1_frame1.jpg: dane dodane.
# a+_000014_1_frame10.jpg: dane dodane.
# a+_000014_1_frame2.jpg: dane dodane.
# a+_000014_1_frame3.jpg: dane dodane.
# a+_000014_1_frame4.jpg: dane dodane.
# a+_000014_1_frame5.jpg: dane dodane.
# a+_000014_1_frame6.jpg: dane dodane.
# a+_000014_1_frame7.jpg: dane dodane.
# a+_000014_1_frame8.jpg: dane dodane.
# a+_000014_1_frame9.jpg: dane dodane.
# a+_000014_2_frame1.jpg: dane dodane.
# a+_000014_2_frame10.jpg: dane dodane.
# a+_000014_2_frame2.jpg: dane dodane.
# a+_000014_2_frame3.jpg: dane dodane.
# a+_000014_2_frame4.jpg: dane dodane.
# a+_000014_2_frame5.jpg: dane dodane.
# a+_000014_2_frame6.jpg: NIE wykryto dłoni
# a+_000014_2_frame7.jpg: NIE wykryto dłoni
# a+_000014_2_frame8.jpg: dane dodane.
# a+_000014_2_frame9.jpg: dane dodane.
# a+_000015_1_frame1.jpg: dane dodane.
# a+_000015_1_frame10.jpg: dane dodane.
# a+_000015_1_frame2.jpg: dane dodane.
# a+_000015_1_frame3.jpg: dane dodane.
# a+_000015_1_frame4.jpg: dane dodane.
# a+_000015_1_frame5.jpg: dane dodane.
# a+_000015_1_frame6.jpg: dane dodane.
# a+_000015_1_frame7.jpg: dane dodane.
# a+_000015_1_frame8.jpg: dane dodane.
# a+_000015_1_frame9.jpg: dane dodane.
# a+_000015_2_frame1.jpg: dane dodane.
# a+_000015_2_frame2.jpg: dane dodane.
# a+_000015_2_frame3.jpg: dane dodane.
# a+_000015_2_frame4.jpg: dane dodane.
# a+_000015_2_frame5.jpg: dane dodane.
# a+_000015_2_frame6.jpg: NIE wykryto dłoni
# a+_000015_2_frame7.jpg: dane dodane.
# a+_000015_2_frame8.jpg: dane dodane.
# a+_000015_2_frame9.jpg: dane dodane.
# a+_000016_1_frame1.jpg: dane dodane.
# a+_000016_1_frame10.jpg: dane dodane.
# a+_000016_1_frame2.jpg: dane dodane.
# a+_000016_1_frame3.jpg: dane dodane.
# a+_000016_1_frame4.jpg: dane dodane.
# a+_000016_1_frame5.jpg: dane dodane.
# a+_000016_1_frame6.jpg: dane dodane.
# a+_000016_1_frame7.jpg: NIE wykryto dłoni
# a+_000016_1_frame8.jpg: dane dodane.
# a+_000016_1_frame9.jpg: dane dodane.
# a+_000016_2_frame1.jpg: dane dodane.
# a+_000016_2_frame10.jpg: dane dodane.
# a+_000016_2_frame2.jpg: NIE wykryto dłoni
# a+_000016_2_frame3.jpg: NIE wykryto dłoni
# a+_000016_2_frame4.jpg: NIE wykryto dłoni
# a+_000016_2_frame5.jpg: dane dodane.
# a+_000016_2_frame6.jpg: dane dodane.
# a+_000016_2_frame7.jpg: dane dodane.
# a+_000016_2_frame8.jpg: dane dodane.
# a+_000016_2_frame9.jpg: dane dodane.
# a+_000017_frame1.jpg: NIE wykryto dłoni
# a+_000017_frame10.jpg: dane dodane.
# a+_000017_frame2.jpg: dane dodane.
# a+_000017_frame3.jpg: NIE wykryto dłoni
# a+_000017_frame4.jpg: dane dodane.
# a+_000017_frame5.jpg: dane dodane.
# a+_000017_frame6.jpg: NIE wykryto dłoni
# a+_000017_frame7.jpg: dane dodane.
# a+_000017_frame8.jpg: dane dodane.
# a+_000017_frame9.jpg: dane dodane.
# a+_000018_1_frame1.jpg: dane dodane.
# a+_000018_1_frame10.jpg: dane dodane.
# a+_000018_1_frame2.jpg: dane dodane.
# a+_000018_1_frame3.jpg: dane dodane.
# a+_000018_1_frame4.jpg: dane dodane.
# a+_000018_1_frame5.jpg: dane dodane.
# a+_000018_1_frame6.jpg: dane dodane.
# a+_000018_1_frame7.jpg: dane dodane.
# a+_000018_1_frame8.jpg: dane dodane.
# a+_000018_1_frame9.jpg: dane dodane.
# a+_000018_2_frame1.jpg: dane dodane.
# a+_000018_2_frame10.jpg: dane dodane.
# a+_000018_2_frame2.jpg: dane dodane.
# a+_000018_2_frame3.jpg: dane dodane.
# a+_000018_2_frame4.jpg: dane dodane.
# a+_000018_2_frame5.jpg: dane dodane.
# a+_000018_2_frame6.jpg: dane dodane.
# a+_000018_2_frame7.jpg: dane dodane.
# a+_000018_2_frame8.jpg: dane dodane.
# a+_000018_2_frame9.jpg: dane dodane.
# a+_000018_3_frame1.jpg: dane dodane.
# a+_000018_3_frame10.jpg: dane dodane.
# a+_000018_3_frame2.jpg: dane dodane.
# a+_000018_3_frame3.jpg: dane dodane.
# a+_000018_3_frame4.jpg: dane dodane.
# a+_000018_3_frame5.jpg: dane dodane.
# a+_000018_3_frame6.jpg: dane dodane.
# a+_000018_3_frame7.jpg: dane dodane.
# a+_000018_3_frame8.jpg: dane dodane.
# a+_000018_3_frame9.jpg: dane dodane.
# a+_00005_1_frame1.jpg: dane dodane.
# a+_00005_1_frame10.jpg: NIE wykryto dłoni
# a+_00005_1_frame2.jpg: dane dodane.
# a+_00005_1_frame3.jpg: dane dodane.
# a+_00005_1_frame4.jpg: dane dodane.
# a+_00005_1_frame5.jpg: dane dodane.
# a+_00005_1_frame6.jpg: dane dodane.
# a+_00005_1_frame7.jpg: dane dodane.
# a+_00005_1_frame8.jpg: dane dodane.
# a+_00005_1_frame9.jpg: NIE wykryto dłoni
# a+_100019_1_frame1.jpg: dane dodane.
# a+_100019_1_frame10.jpg: dane dodane.
# a+_100019_1_frame2.jpg: dane dodane.
# a+_100019_1_frame3.jpg: dane dodane.
# a+_100019_1_frame4.jpg: dane dodane.
# a+_100019_1_frame5.jpg: dane dodane.
# a+_100019_1_frame6.jpg: dane dodane.
# a+_100019_1_frame7.jpg: dane dodane.
# a+_100019_1_frame8.jpg: dane dodane.
# a+_100019_1_frame9.jpg: dane dodane.
# m_a+_000001_1_frame1.jpg: dane dodane.
# m_a+_000001_1_frame10.jpg: dane dodane.
# m_a+_000001_1_frame2.jpg: dane dodane.
# m_a+_000001_1_frame3.jpg: dane dodane.
# m_a+_000001_1_frame4.jpg: dane dodane.
# m_a+_000001_1_frame5.jpg: dane dodane.
# m_a+_000001_1_frame6.jpg: dane dodane.
# m_a+_000001_1_frame7.jpg: dane dodane.
# m_a+_000001_1_frame8.jpg: dane dodane.
# m_a+_000001_1_frame9.jpg: dane dodane.
# m_a+_000002_1_frame1.jpg: dane dodane.
# m_a+_000002_1_frame10.jpg: dane dodane.
# m_a+_000002_1_frame2.jpg: dane dodane.
# m_a+_000002_1_frame3.jpg: dane dodane.
# m_a+_000002_1_frame4.jpg: dane dodane.
# m_a+_000002_1_frame5.jpg: NIE wykryto dłoni
# m_a+_000002_1_frame6.jpg: NIE wykryto dłoni
# m_a+_000002_1_frame7.jpg: NIE wykryto dłoni
# m_a+_000002_1_frame8.jpg: dane dodane.
# m_a+_000002_1_frame9.jpg: dane dodane.
# m_a+_000003_1_frame1.jpg: dane dodane.
# m_a+_000003_1_frame10.jpg: dane dodane.
# m_a+_000003_1_frame2.jpg: dane dodane.
# m_a+_000003_1_frame3.jpg: dane dodane.
# m_a+_000003_1_frame4.jpg: dane dodane.
# m_a+_000003_1_frame5.jpg: dane dodane.
# m_a+_000003_1_frame6.jpg: dane dodane.
# m_a+_000003_1_frame7.jpg: dane dodane.
# m_a+_000003_1_frame8.jpg: dane dodane.
# m_a+_000003_1_frame9.jpg: dane dodane.
# m_a+_000003_3_frame1.jpg: dane dodane.
# m_a+_000003_3_frame10.jpg: dane dodane.
# m_a+_000003_3_frame2.jpg: dane dodane.
# m_a+_000003_3_frame3.jpg: dane dodane.
# m_a+_000003_3_frame4.jpg: dane dodane.
# m_a+_000003_3_frame5.jpg: dane dodane.
# m_a+_000003_3_frame6.jpg: dane dodane.
# m_a+_000003_3_frame7.jpg: dane dodane.
# m_a+_000003_3_frame8.jpg: dane dodane.
# m_a+_000003_3_frame9.jpg: dane dodane.
# m_a+_000004_1_frame1.jpg: dane dodane.
# m_a+_000004_1_frame10.jpg: dane dodane.
# m_a+_000004_1_frame2.jpg: dane dodane.
# m_a+_000004_1_frame3.jpg: dane dodane.
# m_a+_000004_1_frame4.jpg: dane dodane.
# m_a+_000004_1_frame5.jpg: dane dodane.
# m_a+_000004_1_frame6.jpg: dane dodane.
# m_a+_000004_1_frame7.jpg: dane dodane.
# m_a+_000004_1_frame8.jpg: dane dodane.
# m_a+_000004_1_frame9.jpg: dane dodane.
# m_a+_000004_3_frame1.jpg: dane dodane.
# m_a+_000004_3_frame10.jpg: dane dodane.
# m_a+_000004_3_frame2.jpg: dane dodane.
# m_a+_000004_3_frame3.jpg: dane dodane.
# m_a+_000004_3_frame4.jpg: dane dodane.
# m_a+_000004_3_frame5.jpg: dane dodane.
# m_a+_000004_3_frame6.jpg: dane dodane.
# m_a+_000004_3_frame7.jpg: dane dodane.
# m_a+_000004_3_frame8.jpg: dane dodane.
# m_a+_000004_3_frame9.jpg: dane dodane.
# m_a+_000005_3_frame1.jpg: NIE wykryto dłoni
# m_a+_000005_3_frame10.jpg: NIE wykryto dłoni
# m_a+_000005_3_frame2.jpg: NIE wykryto dłoni
# m_a+_000005_3_frame3.jpg: NIE wykryto dłoni
# m_a+_000005_3_frame4.jpg: NIE wykryto dłoni
# m_a+_000005_3_frame5.jpg: NIE wykryto dłoni
# m_a+_000005_3_frame6.jpg: dane dodane.
# m_a+_000005_3_frame7.jpg: dane dodane.
# m_a+_000005_3_frame8.jpg: NIE wykryto dłoni
# m_a+_000005_3_frame9.jpg: NIE wykryto dłoni
# m_a+_000006_1_frame1.jpg: dane dodane.
# m_a+_000006_1_frame10.jpg: dane dodane.
# m_a+_000006_1_frame2.jpg: dane dodane.
# m_a+_000006_1_frame3.jpg: dane dodane.
# m_a+_000006_1_frame4.jpg: dane dodane.
# m_a+_000006_1_frame5.jpg: dane dodane.
# m_a+_000006_1_frame6.jpg: dane dodane.
# m_a+_000006_1_frame7.jpg: dane dodane.
# m_a+_000006_1_frame8.jpg: dane dodane.
# m_a+_000006_1_frame9.jpg: dane dodane.
# m_a+_000006_2_frame1.jpg: dane dodane.
# m_a+_000006_2_frame10.jpg: dane dodane.
# m_a+_000006_2_frame2.jpg: dane dodane.
# m_a+_000006_2_frame3.jpg: dane dodane.
# m_a+_000006_2_frame4.jpg: dane dodane.
# m_a+_000006_2_frame5.jpg: dane dodane.
# m_a+_000006_2_frame6.jpg: dane dodane.
# m_a+_000006_2_frame7.jpg: dane dodane.
# m_a+_000006_2_frame8.jpg: dane dodane.
# m_a+_000006_2_frame9.jpg: dane dodane.
# m_a+_000006_3_frame1.jpg: dane dodane.
# m_a+_000006_3_frame10.jpg: NIE wykryto dłoni
# m_a+_000006_3_frame2.jpg: dane dodane.
# m_a+_000006_3_frame3.jpg: dane dodane.
# m_a+_000006_3_frame4.jpg: dane dodane.
# m_a+_000006_3_frame5.jpg: dane dodane.
# m_a+_000006_3_frame6.jpg: dane dodane.
# m_a+_000006_3_frame7.jpg: dane dodane.
# m_a+_000006_3_frame8.jpg: NIE wykryto dłoni
# m_a+_000006_3_frame9.jpg: dane dodane.
# m_a+_000007_1_frame1.jpg: dane dodane.
# m_a+_000007_1_frame10.jpg: dane dodane.
# m_a+_000007_1_frame2.jpg: dane dodane.
# m_a+_000007_1_frame3.jpg: dane dodane.
# m_a+_000007_1_frame4.jpg: dane dodane.
# m_a+_000007_1_frame5.jpg: dane dodane.
# m_a+_000007_1_frame6.jpg: dane dodane.
# m_a+_000007_1_frame7.jpg: dane dodane.
# m_a+_000007_1_frame8.jpg: dane dodane.
# m_a+_000007_1_frame9.jpg: dane dodane.
# m_a+_000007_2_frame1.jpg: dane dodane.
# m_a+_000007_2_frame10.jpg: NIE wykryto dłoni
# m_a+_000007_2_frame2.jpg: dane dodane.
# m_a+_000007_2_frame3.jpg: dane dodane.
# m_a+_000007_2_frame4.jpg: dane dodane.
# m_a+_000007_2_frame5.jpg: dane dodane.
# m_a+_000007_2_frame6.jpg: dane dodane.
# m_a+_000007_2_frame7.jpg: dane dodane.
# m_a+_000007_2_frame8.jpg: dane dodane.
# m_a+_000007_2_frame9.jpg: dane dodane.
# m_a+_000007_3_frame1.jpg: NIE wykryto dłoni
# m_a+_000007_3_frame10.jpg: NIE wykryto dłoni
# m_a+_000007_3_frame2.jpg: dane dodane.
# m_a+_000007_3_frame3.jpg: dane dodane.
# m_a+_000007_3_frame4.jpg: NIE wykryto dłoni
# m_a+_000007_3_frame5.jpg: dane dodane.
# m_a+_000007_3_frame6.jpg: NIE wykryto dłoni
# m_a+_000007_3_frame7.jpg: dane dodane.
# m_a+_000007_3_frame8.jpg: dane dodane.
# m_a+_000007_3_frame9.jpg: dane dodane.
# m_a+_000008_1_frame1.jpg: dane dodane.
# m_a+_000008_1_frame10.jpg: dane dodane.
# m_a+_000008_1_frame2.jpg: dane dodane.
# m_a+_000008_1_frame3.jpg: dane dodane.
# m_a+_000008_1_frame4.jpg: dane dodane.
# m_a+_000008_1_frame5.jpg: dane dodane.
# m_a+_000008_1_frame6.jpg: dane dodane.
# m_a+_000008_1_frame7.jpg: dane dodane.
# m_a+_000008_1_frame8.jpg: NIE wykryto dłoni
# m_a+_000008_1_frame9.jpg: dane dodane.
# m_a+_000008_2_frame1.jpg: dane dodane.
# m_a+_000008_2_frame10.jpg: dane dodane.
# m_a+_000008_2_frame2.jpg: dane dodane.
# m_a+_000008_2_frame3.jpg: dane dodane.
# m_a+_000008_2_frame4.jpg: dane dodane.
# m_a+_000008_2_frame5.jpg: dane dodane.
# m_a+_000008_2_frame6.jpg: dane dodane.
# m_a+_000008_2_frame7.jpg: dane dodane.
# m_a+_000008_2_frame8.jpg: dane dodane.
# m_a+_000008_2_frame9.jpg: dane dodane.
# m_a+_000008_3_frame1.jpg: dane dodane.
# m_a+_000008_3_frame10.jpg: dane dodane.
# m_a+_000008_3_frame2.jpg: dane dodane.
# m_a+_000008_3_frame3.jpg: dane dodane.
# m_a+_000008_3_frame4.jpg: dane dodane.
# m_a+_000008_3_frame5.jpg: NIE wykryto dłoni
# m_a+_000008_3_frame6.jpg: NIE wykryto dłoni
# m_a+_000008_3_frame7.jpg: dane dodane.
# m_a+_000008_3_frame8.jpg: dane dodane.
# m_a+_000008_3_frame9.jpg: dane dodane.
# m_a+_000009_1_frame1.jpg: dane dodane.
# m_a+_000009_1_frame10.jpg: dane dodane.
# m_a+_000009_1_frame2.jpg: dane dodane.
# m_a+_000009_1_frame3.jpg: dane dodane.
# m_a+_000009_1_frame4.jpg: dane dodane.
# m_a+_000009_1_frame5.jpg: dane dodane.
# m_a+_000009_1_frame6.jpg: dane dodane.
# m_a+_000009_1_frame7.jpg: dane dodane.
# m_a+_000009_1_frame8.jpg: dane dodane.
# m_a+_000009_1_frame9.jpg: dane dodane.
# m_a+_000009_2_frame1.jpg: dane dodane.
# m_a+_000009_2_frame10.jpg: dane dodane.
# m_a+_000009_2_frame2.jpg: dane dodane.
# m_a+_000009_2_frame3.jpg: dane dodane.
# m_a+_000009_2_frame4.jpg: dane dodane.
# m_a+_000009_2_frame5.jpg: dane dodane.
# m_a+_000009_2_frame6.jpg: NIE wykryto dłoni
# m_a+_000009_2_frame7.jpg: dane dodane.
# m_a+_000009_2_frame8.jpg: dane dodane.
# m_a+_000009_2_frame9.jpg: dane dodane.
# m_a+_000010_1_frame1.jpg: dane dodane.
# m_a+_000010_1_frame10.jpg: dane dodane.
# m_a+_000010_1_frame2.jpg: dane dodane.
# m_a+_000010_1_frame3.jpg: dane dodane.
# m_a+_000010_1_frame4.jpg: dane dodane.
# m_a+_000010_1_frame5.jpg: dane dodane.
# m_a+_000010_1_frame6.jpg: dane dodane.
# m_a+_000010_1_frame7.jpg: dane dodane.
# m_a+_000010_1_frame8.jpg: dane dodane.
# m_a+_000010_1_frame9.jpg: dane dodane.
# m_a+_000010_2_frame1.jpg: dane dodane.
# m_a+_000010_2_frame10.jpg: dane dodane.
# m_a+_000010_2_frame2.jpg: dane dodane.
# m_a+_000010_2_frame3.jpg: dane dodane.
# m_a+_000010_2_frame4.jpg: dane dodane.
# m_a+_000010_2_frame5.jpg: dane dodane.
# m_a+_000010_2_frame6.jpg: dane dodane.
# m_a+_000010_2_frame7.jpg: dane dodane.
# m_a+_000010_2_frame8.jpg: dane dodane.
# m_a+_000010_2_frame9.jpg: dane dodane.
# m_a+_000011_1_frame1.jpg: dane dodane.
# m_a+_000011_1_frame10.jpg: dane dodane.
# m_a+_000011_1_frame2.jpg: dane dodane.
# m_a+_000011_1_frame3.jpg: dane dodane.
# m_a+_000011_1_frame4.jpg: dane dodane.
# m_a+_000011_1_frame5.jpg: dane dodane.
# m_a+_000011_1_frame6.jpg: dane dodane.
# m_a+_000011_1_frame7.jpg: dane dodane.
# m_a+_000011_1_frame8.jpg: dane dodane.
# m_a+_000011_1_frame9.jpg: dane dodane.
# m_a+_000011_2_frame1.jpg: dane dodane.
# m_a+_000011_2_frame10.jpg: dane dodane.
# m_a+_000011_2_frame2.jpg: dane dodane.
# m_a+_000011_2_frame3.jpg: dane dodane.
# m_a+_000011_2_frame4.jpg: dane dodane.
# m_a+_000011_2_frame5.jpg: dane dodane.
# m_a+_000011_2_frame6.jpg: dane dodane.
# m_a+_000011_2_frame7.jpg: dane dodane.
# m_a+_000011_2_frame8.jpg: dane dodane.
# m_a+_000011_2_frame9.jpg: dane dodane.
# m_a+_000012_1_frame1.jpg: dane dodane.
# m_a+_000012_1_frame10.jpg: dane dodane.
# m_a+_000012_1_frame2.jpg: dane dodane.
# m_a+_000012_1_frame3.jpg: dane dodane.
# m_a+_000012_1_frame4.jpg: dane dodane.
# m_a+_000012_1_frame5.jpg: dane dodane.
# m_a+_000012_1_frame6.jpg: dane dodane.
# m_a+_000012_1_frame7.jpg: dane dodane.
# m_a+_000012_1_frame8.jpg: dane dodane.
# m_a+_000012_1_frame9.jpg: dane dodane.
# m_a+_000012_2_frame1.jpg: dane dodane.
# m_a+_000012_2_frame10.jpg: dane dodane.
# m_a+_000012_2_frame2.jpg: dane dodane.
# m_a+_000012_2_frame3.jpg: dane dodane.
# m_a+_000012_2_frame4.jpg: dane dodane.
# m_a+_000012_2_frame5.jpg: dane dodane.
# m_a+_000012_2_frame6.jpg: dane dodane.
# m_a+_000012_2_frame7.jpg: NIE wykryto dłoni
# m_a+_000012_2_frame8.jpg: dane dodane.
# m_a+_000012_2_frame9.jpg: dane dodane.
# m_a+_000013_1_frame1.jpg: dane dodane.
# m_a+_000013_1_frame10.jpg: dane dodane.
# m_a+_000013_1_frame2.jpg: dane dodane.
# m_a+_000013_1_frame3.jpg: dane dodane.
# m_a+_000013_1_frame4.jpg: dane dodane.
# m_a+_000013_1_frame5.jpg: dane dodane.
# m_a+_000013_1_frame6.jpg: dane dodane.
# m_a+_000013_1_frame7.jpg: dane dodane.
# m_a+_000013_1_frame8.jpg: dane dodane.
# m_a+_000013_1_frame9.jpg: dane dodane.
# m_a+_000013_2_frame1.jpg: dane dodane.
# m_a+_000013_2_frame10.jpg: dane dodane.
# m_a+_000013_2_frame2.jpg: dane dodane.
# m_a+_000013_2_frame3.jpg: dane dodane.
# m_a+_000013_2_frame4.jpg: dane dodane.
# m_a+_000013_2_frame5.jpg: dane dodane.
# m_a+_000013_2_frame6.jpg: dane dodane.
# m_a+_000013_2_frame7.jpg: dane dodane.
# m_a+_000013_2_frame8.jpg: dane dodane.
# m_a+_000013_2_frame9.jpg: dane dodane.
# m_a+_000014_1_frame1.jpg: dane dodane.
# m_a+_000014_1_frame10.jpg: dane dodane.
# m_a+_000014_1_frame2.jpg: dane dodane.
# m_a+_000014_1_frame3.jpg: dane dodane.
# m_a+_000014_1_frame4.jpg: dane dodane.
# m_a+_000014_1_frame5.jpg: dane dodane.
# m_a+_000014_1_frame6.jpg: dane dodane.
# m_a+_000014_1_frame7.jpg: dane dodane.
# m_a+_000014_1_frame8.jpg: dane dodane.
# m_a+_000014_1_frame9.jpg: dane dodane.
# m_a+_000014_2_frame1.jpg: dane dodane.
# m_a+_000014_2_frame10.jpg: dane dodane.
# m_a+_000014_2_frame2.jpg: dane dodane.
# m_a+_000014_2_frame3.jpg: dane dodane.
# m_a+_000014_2_frame4.jpg: dane dodane.
# m_a+_000014_2_frame5.jpg: dane dodane.
# m_a+_000014_2_frame6.jpg: NIE wykryto dłoni
# m_a+_000014_2_frame7.jpg: NIE wykryto dłoni
# m_a+_000014_2_frame8.jpg: dane dodane.
# m_a+_000014_2_frame9.jpg: dane dodane.
# m_a+_000015_1_frame1.jpg: dane dodane.
# m_a+_000015_1_frame10.jpg: dane dodane.
# m_a+_000015_1_frame2.jpg: dane dodane.
# m_a+_000015_1_frame3.jpg: dane dodane.
# m_a+_000015_1_frame4.jpg: dane dodane.
# m_a+_000015_1_frame5.jpg: dane dodane.
# m_a+_000015_1_frame6.jpg: dane dodane.
# m_a+_000015_1_frame7.jpg: dane dodane.
# m_a+_000015_1_frame8.jpg: dane dodane.
# m_a+_000015_1_frame9.jpg: dane dodane.
# m_a+_000015_2_frame1.jpg: dane dodane.
# m_a+_000015_2_frame2.jpg: dane dodane.
# m_a+_000015_2_frame3.jpg: dane dodane.
# m_a+_000015_2_frame4.jpg: dane dodane.
# m_a+_000015_2_frame5.jpg: dane dodane.
# m_a+_000015_2_frame6.jpg: NIE wykryto dłoni
# m_a+_000015_2_frame7.jpg: dane dodane.
# m_a+_000015_2_frame8.jpg: dane dodane.
# m_a+_000015_2_frame9.jpg: dane dodane.
# m_a+_000016_1_frame1.jpg: dane dodane.
# m_a+_000016_1_frame10.jpg: dane dodane.
# m_a+_000016_1_frame2.jpg: dane dodane.
# m_a+_000016_1_frame3.jpg: dane dodane.
# m_a+_000016_1_frame4.jpg: dane dodane.
# m_a+_000016_1_frame5.jpg: dane dodane.
# m_a+_000016_1_frame6.jpg: dane dodane.
# m_a+_000016_1_frame7.jpg: NIE wykryto dłoni
# m_a+_000016_1_frame8.jpg: dane dodane.
# m_a+_000016_1_frame9.jpg: dane dodane.
# m_a+_000016_2_frame1.jpg: dane dodane.
# m_a+_000016_2_frame10.jpg: dane dodane.
# m_a+_000016_2_frame2.jpg: NIE wykryto dłoni
# m_a+_000016_2_frame3.jpg: NIE wykryto dłoni
# m_a+_000016_2_frame4.jpg: NIE wykryto dłoni
# m_a+_000016_2_frame5.jpg: dane dodane.
# m_a+_000016_2_frame6.jpg: dane dodane.
# m_a+_000016_2_frame7.jpg: dane dodane.
# m_a+_000016_2_frame8.jpg: dane dodane.
# m_a+_000016_2_frame9.jpg: dane dodane.
# m_a+_000017_frame1.jpg: NIE wykryto dłoni
# m_a+_000017_frame10.jpg: NIE wykryto dłoni
# m_a+_000017_frame2.jpg: NIE wykryto dłoni
# m_a+_000017_frame3.jpg: NIE wykryto dłoni
# m_a+_000017_frame4.jpg: dane dodane.
# m_a+_000017_frame5.jpg: dane dodane.
# m_a+_000017_frame6.jpg: dane dodane.
# m_a+_000017_frame7.jpg: dane dodane.
# m_a+_000017_frame8.jpg: dane dodane.
# m_a+_000017_frame9.jpg: NIE wykryto dłoni
# m_a+_000018_1_frame1.jpg: dane dodane.
# m_a+_000018_1_frame10.jpg: NIE wykryto dłoni
# m_a+_000018_1_frame2.jpg: NIE wykryto dłoni
# m_a+_000018_1_frame3.jpg: dane dodane.
# m_a+_000018_1_frame4.jpg: NIE wykryto dłoni
# m_a+_000018_1_frame5.jpg: NIE wykryto dłoni
# m_a+_000018_1_frame6.jpg: dane dodane.
# m_a+_000018_1_frame7.jpg: dane dodane.
# m_a+_000018_1_frame8.jpg: NIE wykryto dłoni
# m_a+_000018_1_frame9.jpg: NIE wykryto dłoni
# m_a+_000018_2_frame1.jpg: dane dodane.
# m_a+_000018_2_frame10.jpg: dane dodane.
# m_a+_000018_2_frame2.jpg: dane dodane.
# m_a+_000018_2_frame3.jpg: dane dodane.
# m_a+_000018_2_frame4.jpg: dane dodane.
# m_a+_000018_2_frame5.jpg: dane dodane.
# m_a+_000018_2_frame6.jpg: dane dodane.
# m_a+_000018_2_frame7.jpg: dane dodane.
# m_a+_000018_2_frame8.jpg: dane dodane.
# m_a+_000018_2_frame9.jpg: dane dodane.
# m_a+_000018_3_frame1.jpg: NIE wykryto dłoni
# m_a+_000018_3_frame10.jpg: NIE wykryto dłoni
# m_a+_000018_3_frame2.jpg: NIE wykryto dłoni
# m_a+_000018_3_frame3.jpg: NIE wykryto dłoni
# m_a+_000018_3_frame4.jpg: NIE wykryto dłoni
# m_a+_000018_3_frame5.jpg: NIE wykryto dłoni
# m_a+_000018_3_frame6.jpg: dane dodane.
# m_a+_000018_3_frame7.jpg: NIE wykryto dłoni
# m_a+_000018_3_frame8.jpg: dane dodane.
# m_a+_000018_3_frame9.jpg: NIE wykryto dłoni
# m_a+_00005_1_frame1.jpg: dane dodane.
# m_a+_00005_1_frame10.jpg: NIE wykryto dłoni
# m_a+_00005_1_frame2.jpg: dane dodane.
# m_a+_00005_1_frame3.jpg: dane dodane.
# m_a+_00005_1_frame4.jpg: dane dodane.
# m_a+_00005_1_frame5.jpg: dane dodane.
# m_a+_00005_1_frame6.jpg: dane dodane.
# m_a+_00005_1_frame7.jpg: dane dodane.
# m_a+_00005_1_frame8.jpg: dane dodane.
# m_a+_00005_1_frame9.jpg: dane dodane.
# m_a+_100019_1_frame1.jpg: dane dodane.
# m_a+_100019_1_frame10.jpg: dane dodane.
# m_a+_100019_1_frame2.jpg: dane dodane.
# m_a+_100019_1_frame3.jpg: dane dodane.
# m_a+_100019_1_frame4.jpg: dane dodane.
# m_a+_100019_1_frame5.jpg: dane dodane.
# m_a+_100019_1_frame6.jpg: dane dodane.
# m_a+_100019_1_frame7.jpg: dane dodane.
# m_a+_100019_1_frame8.jpg: dane dodane.
# m_a+_100019_1_frame9.jpg: dane dodane.
#  Przetwarzanie symbolu: c+_images
# c+_000001_frame1.jpg: dane dodane.
# c+_000001_frame10.jpg: dane dodane.
# c+_000001_frame2.jpg: dane dodane.
# c+_000001_frame3.jpg: dane dodane.
# c+_000001_frame4.jpg: dane dodane.
# m_c+_000001_frame4.jpg: dane dodane.
# m_c+_000001_frame5.jpg: dane dodane.
# m_c+_000001_frame6.jpg: dane dodane.
# m_c+_000001_frame7.jpg: dane dodane.
# m_c+_000001_frame8.jpg: dane dodane.
# m_c+_000001_frame9.jpg: dane dodane.
# m_c+_000002_frame1.jpg: dane dodane.
# m_c+_000002_frame10.jpg: dane dodane.
# m_c+_000002_frame2.jpg: dane dodane.
# m_c+_000002_frame3.jpg: dane dodane.
# m_c+_000002_frame4.jpg: dane dodane.
# m_c+_000002_frame5.jpg: dane dodane.
# m_c+_000002_frame6.jpg: dane dodane.
# m_c+_000002_frame7.jpg: dane dodane.
# m_c+_000002_frame8.jpg: dane dodane.
# m_c+_000002_frame9.jpg: dane dodane.
# m_c+_000003_3_frame1.jpg: dane dodane.
# m_c+_000003_3_frame10.jpg: dane dodane.
# m_c+_000003_3_frame2.jpg: dane dodane.
# m_c+_000003_3_frame3.jpg: dane dodane.
# m_c+_000003_3_frame4.jpg: dane dodane.
# m_c+_000003_3_frame5.jpg: dane dodane.
# m_c+_000003_3_frame6.jpg: dane dodane.
# m_c+_000003_3_frame7.jpg: dane dodane.
# m_c+_000003_3_frame8.jpg: dane dodane.
# m_c+_000003_3_frame9.jpg: dane dodane.
# m_c+_000004_3_frame1.jpg: NIE wykryto dłoni
# m_c+_000004_3_frame10.jpg: dane dodane.
# m_c+_000004_3_frame2.jpg: NIE wykryto dłoni
# m_c+_000004_3_frame3.jpg: NIE wykryto dłoni
# m_c+_000004_3_frame4.jpg: dane dodane.
# m_c+_000004_3_frame5.jpg: dane dodane.
# m_c+_000004_3_frame6.jpg: dane dodane.
# m_c+_000004_3_frame7.jpg: dane dodane.
# m_c+_000004_3_frame8.jpg: dane dodane.
# m_c+_000004_3_frame9.jpg: dane dodane.
# m_c+_000005_3_frame1.jpg: NIE wykryto dłoni
# m_c+_000005_3_frame10.jpg: dane dodane.
# m_c+_000005_3_frame2.jpg: NIE wykryto dłoni
# m_c+_000005_3_frame3.jpg: NIE wykryto dłoni
# m_c+_000005_3_frame4.jpg: dane dodane.
# m_c+_000005_3_frame5.jpg: NIE wykryto dłoni
# m_c+_000005_3_frame6.jpg: dane dodane.
# m_c+_000005_3_frame7.jpg: NIE wykryto dłoni
# m_c+_000005_3_frame8.jpg: dane dodane.
# m_c+_000005_3_frame9.jpg: NIE wykryto dłoni
# m_c+_000006_02_frame1.jpg: dane dodane.
# m_c+_000006_02_frame10.jpg: dane dodane.
# m_c+_000006_02_frame2.jpg: dane dodane.
# m_c+_000006_02_frame3.jpg: dane dodane.
# m_c+_000006_02_frame4.jpg: dane dodane.
# m_c+_000006_02_frame5.jpg: dane dodane.
# m_c+_000006_02_frame6.jpg: dane dodane.
# m_c+_000006_02_frame7.jpg: dane dodane.
# m_c+_000006_02_frame8.jpg: dane dodane.
# m_c+_000006_02_frame9.jpg: dane dodane.
# m_c+_000006_3_frame1.jpg: dane dodane.
# m_c+_000006_3_frame10.jpg: dane dodane.
# m_c+_000006_3_frame2.jpg: dane dodane.
# m_c+_000006_3_frame3.jpg: dane dodane.
# m_c+_000006_3_frame4.jpg: dane dodane.
# m_c+_000006_3_frame5.jpg: dane dodane.
# m_c+_000006_3_frame6.jpg: NIE wykryto dłoni
# m_c+_000006_3_frame7.jpg: NIE wykryto dłoni
# m_c+_000006_3_frame8.jpg: dane dodane.
# m_c+_000006_3_frame9.jpg: NIE wykryto dłoni
# m_c+_000007_02_frame1.jpg: dane dodane.
# m_c+_000007_02_frame10.jpg: dane dodane.
# m_c+_000007_02_frame2.jpg: dane dodane.
# m_c+_000007_02_frame3.jpg: dane dodane.
# m_c+_000007_02_frame4.jpg: dane dodane.
# m_c+_000007_02_frame5.jpg: dane dodane.
# m_c+_000007_02_frame6.jpg: dane dodane.
# m_c+_000007_02_frame7.jpg: dane dodane.
# m_c+_000007_02_frame8.jpg: NIE wykryto dłoni
# m_c+_000007_02_frame9.jpg: dane dodane.
# m_c+_000007_3_frame1.jpg: dane dodane.
# m_c+_000007_3_frame2.jpg: dane dodane.
# m_c+_000007_3_frame3.jpg: dane dodane.
# m_c+_000007_3_frame4.jpg: dane dodane.
# m_c+_000007_3_frame5.jpg: NIE wykryto dłoni
# m_c+_000007_3_frame6.jpg: NIE wykryto dłoni
# m_c+_000007_3_frame7.jpg: dane dodane.
# m_c+_000007_3_frame8.jpg: dane dodane.
# m_c+_000007_3_frame9.jpg: dane dodane.
# m_c+_000008_02_frame1.jpg: dane dodane.
# m_c+_000008_02_frame10.jpg: dane dodane.
# m_c+_000008_02_frame2.jpg: dane dodane.
# m_c+_000008_02_frame3.jpg: dane dodane.
# m_c+_000008_02_frame4.jpg: dane dodane.
# m_c+_000008_02_frame5.jpg: dane dodane.
# m_c+_000008_02_frame6.jpg: dane dodane.
# m_c+_000008_02_frame7.jpg: dane dodane.
# m_c+_000008_02_frame8.jpg: dane dodane.
# m_c+_000008_02_frame9.jpg: dane dodane.
# m_c+_000008_3_frame1.jpg: dane dodane.
# m_c+_000008_3_frame10.jpg: NIE wykryto dłoni
# m_c+_000008_3_frame2.jpg: dane dodane.
# m_c+_000008_3_frame3.jpg: dane dodane.
# m_c+_000008_3_frame4.jpg: dane dodane.
# m_c+_000008_3_frame5.jpg: dane dodane.
# m_c+_000008_3_frame6.jpg: NIE wykryto dłoni
# m_c+_000008_3_frame7.jpg: NIE wykryto dłoni
# m_c+_000008_3_frame8.jpg: NIE wykryto dłoni
# m_c+_000008_3_frame9.jpg: NIE wykryto dłoni
# m_c+_000009_02_frame1.jpg: dane dodane.
# m_c+_000009_02_frame10.jpg: NIE wykryto dłoni
# m_c+_000009_02_frame2.jpg: dane dodane.
# m_c+_000009_02_frame3.jpg: dane dodane.
# m_c+_000009_02_frame4.jpg: dane dodane.
# m_c+_000009_02_frame5.jpg: dane dodane.
# m_c+_000009_02_frame6.jpg: dane dodane.
# m_c+_000009_02_frame7.jpg: NIE wykryto dłoni
# m_c+_000009_02_frame8.jpg: dane dodane.
# m_c+_000009_02_frame9.jpg: dane dodane.
# m_c+_000010_2_frame1.jpg: dane dodane.
# m_c+_000010_2_frame10.jpg: dane dodane.
# m_c+_000010_2_frame2.jpg: dane dodane.
# m_c+_000010_2_frame3.jpg: dane dodane.
# ...
# m_z_18_1_frame2.jpg: dane dodane.
# m_z_18_1_frame3.jpg: dane dodane.
# m_z_18_1_frame4.jpg: dane dodane.
# m_z_18_1_frame5.jpg: dane dodane.
# m_z_18_1_frame6.jpg: dane dodane.
# m_z_18_1_frame7.jpg: dane dodane.
# m_z_18_1_frame8.jpg: dane dodane.
# m_z_18_1_frame9.jpg: dane dodane.
# m_z_3_1_frame1.jpg: dane dodane.
# m_z_3_1_frame10.jpg: dane dodane.
# m_z_3_1_frame2.jpg: dane dodane.
# m_z_3_1_frame3.jpg: dane dodane.
# m_z_3_1_frame4.jpg: dane dodane.
# m_z_3_1_frame5.jpg: dane dodane.
# m_z_3_1_frame6.jpg: dane dodane.
# m_z_3_1_frame7.jpg: dane dodane.
# m_z_3_1_frame8.jpg: dane dodane.
# m_z_3_1_frame9.jpg: dane dodane.
# m_z_4_1_frame1.jpg: dane dodane.
# m_z_4_1_frame10.jpg: dane dodane.
# m_z_4_1_frame2.jpg: dane dodane.
# m_z_4_1_frame3.jpg: dane dodane.
# m_z_4_1_frame4.jpg: dane dodane.
# m_z_4_1_frame5.jpg: dane dodane.
# m_z_4_1_frame6.jpg: dane dodane.
# m_z_4_1_frame7.jpg: dane dodane.
# m_z_4_1_frame8.jpg: dane dodane.
# m_z_4_1_frame9.jpg: dane dodane.
# m_z_5_1_frame1.jpg: dane dodane.
# m_z_5_1_frame10.jpg: NIE wykryto dłoni
# m_z_5_1_frame2.jpg: dane dodane.
# m_z_5_1_frame3.jpg: dane dodane.
# m_z_5_1_frame4.jpg: dane dodane.
# m_z_5_1_frame5.jpg: dane dodane.
# m_z_5_1_frame6.jpg: dane dodane.
# m_z_5_1_frame7.jpg: dane dodane.
# m_z_5_1_frame8.jpg: NIE wykryto dłoni
# m_z_5_1_frame9.jpg: NIE wykryto dłoni
# m_z_6_1_frame1.jpg: dane dodane.
# m_z_6_1_frame10.jpg: dane dodane.
# m_z_6_1_frame2.jpg: dane dodane.
# m_z_6_1_frame3.jpg: dane dodane.
# m_z_6_1_frame4.jpg: dane dodane.
# m_z_6_1_frame5.jpg: dane dodane.
# m_z_6_1_frame6.jpg: dane dodane.
# m_z_6_1_frame7.jpg: dane dodane.
# m_z_6_1_frame8.jpg: dane dodane.
# m_z_6_1_frame9.jpg: dane dodane.
# m_z_7_1_frame1.jpg: dane dodane.
# m_z_7_1_frame10.jpg: dane dodane.
# m_z_7_1_frame2.jpg: dane dodane.
# m_z_7_1_frame3.jpg: dane dodane.
# m_z_7_1_frame4.jpg: dane dodane.
# m_z_7_1_frame5.jpg: dane dodane.
# m_z_7_1_frame6.jpg: dane dodane.
# m_z_7_1_frame7.jpg: dane dodane.
# m_z_7_1_frame8.jpg: NIE wykryto dłoni
# m_z_7_1_frame9.jpg: dane dodane.
# m_z_8_1_frame1.jpg: dane dodane.
# m_z_8_1_frame10.jpg: dane dodane.
# m_z_8_1_frame2.jpg: dane dodane.
# m_z_8_1_frame3.jpg: dane dodane.
# m_z_8_1_frame4.jpg: dane dodane.
# m_z_8_1_frame5.jpg: dane dodane.
# m_z_8_1_frame6.jpg: dane dodane.
# m_z_8_1_frame7.jpg: dane dodane.
# m_z_8_1_frame8.jpg: dane dodane.
# m_z_8_1_frame9.jpg: dane dodane.
# m_z_9_1_frame1.jpg: dane dodane.
# m_z_9_1_frame10.jpg: dane dodane.
# m_z_9_1_frame2.jpg: dane dodane.
# m_z_9_1_frame3.jpg: dane dodane.
# m_z_9_1_frame4.jpg: dane dodane.
# m_z_9_1_frame5.jpg: dane dodane.
# m_z_9_1_frame6.jpg: dane dodane.
# m_z_9_1_frame7.jpg: dane dodane.
# m_z_9_1_frame8.jpg: dane dodane.
# m_z_9_1_frame9.jpg: dane dodane.
# z_000001_frame1.jpg: dane dodane.
# z_000001_frame10.jpg: dane dodane.
# z_000001_frame2.jpg: dane dodane.
# z_000001_frame3.jpg: dane dodane.
# z_000001_frame4.jpg: dane dodane.
# z_000001_frame5.jpg: NIE wykryto dłoni
# z_000001_frame6.jpg: dane dodane.
# z_000001_frame7.jpg: NIE wykryto dłoni
# z_000001_frame8.jpg: NIE wykryto dłoni
# z_000001_frame9.jpg: dane dodane.
# z_000002_frame1.jpg: dane dodane.
# z_000002_frame10.jpg: dane dodane.
# z_000002_frame2.jpg: dane dodane.
# z_000002_frame3.jpg: dane dodane.
# z_000002_frame4.jpg: NIE wykryto dłoni
# z_000002_frame5.jpg: dane dodane.
# z_000002_frame6.jpg: dane dodane.
# z_000002_frame7.jpg: NIE wykryto dłoni
# z_000002_frame8.jpg: dane dodane.
# z_000002_frame9.jpg: dane dodane.
# z_000003_3_frame1.jpg: dane dodane.
# z_000003_3_frame10.jpg: dane dodane.
# z_000003_3_frame2.jpg: dane dodane.
# z_000003_3_frame3.jpg: dane dodane.
# z_000003_3_frame4.jpg: dane dodane.
# z_000003_3_frame5.jpg: dane dodane.
# z_000003_3_frame6.jpg: dane dodane.
# z_000003_3_frame7.jpg: dane dodane.
# z_000003_3_frame8.jpg: dane dodane.
# z_000003_3_frame9.jpg: dane dodane.
# z_000004_3_frame1.jpg: dane dodane.
# z_000004_3_frame10.jpg: dane dodane.
# z_000004_3_frame2.jpg: dane dodane.
# z_000004_3_frame3.jpg: dane dodane.
# z_000004_3_frame4.jpg: dane dodane.
# z_000004_3_frame5.jpg: dane dodane.
# z_000004_3_frame6.jpg: dane dodane.
# z_000004_3_frame7.jpg: dane dodane.
# z_000004_3_frame8.jpg: dane dodane.
# z_000004_3_frame9.jpg: NIE wykryto dłoni
# z_000005_3_frame1.jpg: dane dodane.
# z_000005_3_frame10.jpg: dane dodane.
# z_000005_3_frame2.jpg: dane dodane.
# z_000005_3_frame3.jpg: dane dodane.
# z_000005_3_frame4.jpg: dane dodane.
# z_000005_3_frame5.jpg: dane dodane.
# z_000005_3_frame6.jpg: NIE wykryto dłoni
# z_000005_3_frame7.jpg: NIE wykryto dłoni
# z_000009_02_frame10.jpg: dane dodane.
# z_000009_02_frame2.jpg: dane dodane.
# z_000009_02_frame3.jpg: dane dodane.
# z_000009_02_frame4.jpg: dane dodane.
# z_000009_02_frame5.jpg: dane dodane.
# z_000009_02_frame6.jpg: dane dodane.
# z_000009_02_frame7.jpg: dane dodane.
# z_000009_02_frame8.jpg: dane dodane.
# z_000009_02_frame9.jpg: dane dodane.
# z_000010_2_frame1.jpg: dane dodane.
# z_000010_2_frame10.jpg: NIE wykryto dłoni
# z_000010_2_frame2.jpg: dane dodane.
# z_000010_2_frame3.jpg: NIE wykryto dłoni
# z_000010_2_frame4.jpg: NIE wykryto dłoni
# z_000010_2_frame5.jpg: dane dodane.
# z_000010_2_frame6.jpg: dane dodane.
# z_000010_2_frame7.jpg: NIE wykryto dłoni
# z_000010_2_frame8.jpg: dane dodane.
# z_000010_2_frame9.jpg: dane dodane.
# z_000011_2_frame1.jpg: dane dodane.
# z_000011_2_frame10.jpg: NIE wykryto dłoni
# z_000011_2_frame2.jpg: dane dodane.
# z_000011_2_frame3.jpg: dane dodane.
# z_000011_2_frame4.jpg: NIE wykryto dłoni
# z_000011_2_frame5.jpg: NIE wykryto dłoni
# z_000011_2_frame6.jpg: dane dodane.
# z_000011_2_frame7.jpg: NIE wykryto dłoni
# z_000011_2_frame8.jpg: NIE wykryto dłoni
# z_000011_2_frame9.jpg: NIE wykryto dłoni
# z_000012_02_frame1.jpg: dane dodane.
# z_000012_02_frame10.jpg: NIE wykryto dłoni
# z_000012_02_frame2.jpg: dane dodane.
# z_000012_02_frame3.jpg: dane dodane.
# z_000012_02_frame4.jpg: dane dodane.
# z_000012_02_frame5.jpg: dane dodane.
# z_000012_02_frame6.jpg: dane dodane.
# z_000012_02_frame7.jpg: NIE wykryto dłoni
# z_000012_02_frame8.jpg: dane dodane.
# z_000012_02_frame9.jpg: NIE wykryto dłoni
# z_000013_02_frame1.jpg: dane dodane.
# z_000013_02_frame10.jpg: dane dodane.
# z_000013_02_frame2.jpg: dane dodane.
# z_000013_02_frame3.jpg: dane dodane.
# z_000013_02_frame4.jpg: dane dodane.
# z_000013_02_frame5.jpg: dane dodane.
# z_000013_02_frame6.jpg: dane dodane.
# z_000013_02_frame7.jpg: dane dodane.
# z_000013_02_frame8.jpg: dane dodane.
# z_000013_02_frame9.jpg: dane dodane.
# z_000014_02_frame1.jpg: dane dodane.
# z_000014_02_frame10.jpg: NIE wykryto dłoni
# z_000014_02_frame2.jpg: dane dodane.
# z_000014_02_frame3.jpg: dane dodane.
# z_000014_02_frame4.jpg: dane dodane.
# z_000014_02_frame5.jpg: dane dodane.
# z_000014_02_frame6.jpg: NIE wykryto dłoni
# z_000014_02_frame7.jpg: NIE wykryto dłoni
# z_000014_02_frame8.jpg: NIE wykryto dłoni
# z_000014_02_frame9.jpg: dane dodane.
# z_000015_02_frame1.jpg: dane dodane.
# z_000015_02_frame10.jpg: NIE wykryto dłoni
# z_000015_02_frame2.jpg: dane dodane.
# z_000015_02_frame3.jpg: dane dodane.
# z_000015_02_frame4.jpg: dane dodane.
# z_000015_02_frame5.jpg: dane dodane.
# z_000015_02_frame6.jpg: dane dodane.
# z_000015_02_frame7.jpg: dane dodane.
# z_000015_02_frame8.jpg: dane dodane.
# z_000015_02_frame9.jpg: NIE wykryto dłoni
# z_000016_02_frame1.jpg: dane dodane.
# z_000016_02_frame10.jpg: NIE wykryto dłoni
# z_000016_02_frame2.jpg: dane dodane.
# z_000016_02_frame3.jpg: dane dodane.
# z_000016_02_frame4.jpg: dane dodane.
# z_000016_02_frame5.jpg: NIE wykryto dłoni
# z_000016_02_frame6.jpg: NIE wykryto dłoni
# z_000016_02_frame7.jpg: dane dodane.
# z_000016_02_frame8.jpg: dane dodane.
# z_000016_02_frame9.jpg: NIE wykryto dłoni
# z_000018_02_frame1.jpg: dane dodane.
# z_000018_02_frame10.jpg: dane dodane.
# z_000018_02_frame2.jpg: dane dodane.
# z_000018_02_frame3.jpg: dane dodane.
# z_000018_02_frame4.jpg: dane dodane.
# z_000018_02_frame5.jpg: dane dodane.
# z_000018_02_frame6.jpg: dane dodane.
# z_000018_02_frame7.jpg: dane dodane.
# z_000018_02_frame8.jpg: dane dodane.
# z_000018_02_frame9.jpg: dane dodane.
# z_000018_3_frame1.jpg: dane dodane.
# z_000018_3_frame10.jpg: dane dodane.
# z_000018_3_frame2.jpg: dane dodane.
# z_000018_3_frame3.jpg: dane dodane.
# z_000018_3_frame4.jpg: dane dodane.
# z_000018_3_frame5.jpg: dane dodane.
# z_000018_3_frame6.jpg: dane dodane.
# z_000018_3_frame7.jpg: dane dodane.
# z_000018_3_frame8.jpg: dane dodane.
# z_000018_3_frame9.jpg: dane dodane.
# z_100019_1_frame1.jpg: dane dodane.
# z_100019_1_frame10.jpg: dane dodane.
# z_100019_1_frame2.jpg: dane dodane.
# z_100019_1_frame3.jpg: dane dodane.
# z_100019_1_frame4.jpg: dane dodane.
# z_100019_1_frame5.jpg: dane dodane.
# z_100019_1_frame6.jpg: dane dodane.
# z_100019_1_frame7.jpg: dane dodane.
# z_100019_1_frame8.jpg: dane dodane.
# z_100019_1_frame9.jpg: dane dodane.
# z_10_1_frame1.jpg: dane dodane.
# z_10_1_frame10.jpg: dane dodane.
# z_10_1_frame2.jpg: dane dodane.
# z_10_1_frame3.jpg: dane dodane.
# z_10_1_frame4.jpg: dane dodane.
# z_10_1_frame5.jpg: dane dodane.
# z_10_1_frame6.jpg: dane dodane.
# z_10_1_frame7.jpg: dane dodane.
# z_10_1_frame8.jpg: dane dodane.
# z_10_1_frame9.jpg: dane dodane.
# z_11_1_frame1.jpg: dane dodane.
# z_11_1_frame10.jpg: dane dodane.
# z_11_1_frame2.jpg: dane dodane.
# z_11_1_frame3.jpg: dane dodane.
# z_11_1_frame4.jpg: dane dodane.
# z_11_1_frame5.jpg: dane dodane.
# z_11_1_frame6.jpg: dane dodane.
# z_11_1_frame7.jpg: dane dodane.
# z_11_1_frame8.jpg: dane dodane.
# z_11_1_frame9.jpg: dane dodane.
# z_12_1_frame1.jpg: dane dodane.
# z_12_1_frame10.jpg: dane dodane.
# z_12_1_frame2.jpg: dane dodane.
# z_12_1_frame3.jpg: dane dodane.
# z_12_1_frame4.jpg: dane dodane.
# z_12_1_frame5.jpg: dane dodane.
# z_12_1_frame6.jpg: dane dodane.
# z_12_1_frame7.jpg: dane dodane.
# z_12_1_frame8.jpg: dane dodane.
# z_12_1_frame9.jpg: dane dodane.
# z_13_1_frame1.jpg: dane dodane.
# z_13_1_frame10.jpg: dane dodane.
# z_13_1_frame2.jpg: dane dodane.
# z_13_1_frame3.jpg: dane dodane.
# z_13_1_frame4.jpg: dane dodane.
# z_13_1_frame5.jpg: dane dodane.
# z_13_1_frame6.jpg: dane dodane.
# z_13_1_frame7.jpg: dane dodane.
# z_13_1_frame8.jpg: dane dodane.
# z_13_1_frame9.jpg: dane dodane.
# z_14_1_frame1.jpg: dane dodane.
# z_14_1_frame10.jpg: dane dodane.
# z_14_1_frame2.jpg: dane dodane.
# z_14_1_frame3.jpg: dane dodane.
# z_14_1_frame4.jpg: dane dodane.
# z_14_1_frame5.jpg: dane dodane.
# z_14_1_frame6.jpg: dane dodane.
# z_14_1_frame7.jpg: dane dodane.
# z_14_1_frame8.jpg: dane dodane.
# z_14_1_frame9.jpg: dane dodane.
# z_15_1_frame1.jpg: dane dodane.
# z_15_1_frame10.jpg: dane dodane.
# z_15_1_frame2.jpg: dane dodane.
# z_15_1_frame3.jpg: dane dodane.
# z_15_1_frame4.jpg: dane dodane.
# z_15_1_frame5.jpg: dane dodane.
# z_15_1_frame6.jpg: dane dodane.
# z_15_1_frame7.jpg: dane dodane.
# z_15_1_frame8.jpg: dane dodane.
# z_15_1_frame9.jpg: dane dodane.
# z_16_1_frame1.jpg: dane dodane.
# z_16_1_frame10.jpg: NIE wykryto dłoni
# z_16_1_frame2.jpg: dane dodane.
# z_16_1_frame3.jpg: dane dodane.
# z_16_1_frame4.jpg: dane dodane.
# z_16_1_frame5.jpg: dane dodane.
# z_16_1_frame6.jpg: NIE wykryto dłoni
# z_16_1_frame7.jpg: dane dodane.
# z_16_1_frame8.jpg: dane dodane.
# z_16_1_frame9.jpg: NIE wykryto dłoni
# z_17_frame1.jpg: NIE wykryto dłoni
# z_17_frame10.jpg: dane dodane.
# z_17_frame2.jpg: NIE wykryto dłoni
# z_17_frame3.jpg: dane dodane.
# z_17_frame4.jpg: dane dodane.
# z_17_frame5.jpg: dane dodane.
# z_17_frame6.jpg: dane dodane.
# z_17_frame7.jpg: dane dodane.
# z_17_frame8.jpg: dane dodane.
# z_17_frame9.jpg: dane dodane.
# z_18_1_frame1.jpg: dane dodane.
# z_18_1_frame10.jpg: dane dodane.
# z_18_1_frame2.jpg: dane dodane.
# z_18_1_frame3.jpg: dane dodane.
# z_18_1_frame4.jpg: dane dodane.
# z_18_1_frame5.jpg: dane dodane.
# z_18_1_frame6.jpg: dane dodane.
# z_18_1_frame7.jpg: dane dodane.
# z_18_1_frame8.jpg: dane dodane.
# z_18_1_frame9.jpg: dane dodane.
# z_3_1_frame1.jpg: dane dodane.
# z_3_1_frame10.jpg: dane dodane.
# z_3_1_frame2.jpg: dane dodane.
# z_3_1_frame3.jpg: dane dodane.
# z_3_1_frame4.jpg: dane dodane.
# z_3_1_frame5.jpg: dane dodane.
# z_3_1_frame6.jpg: dane dodane.
# z_3_1_frame7.jpg: dane dodane.
# z_3_1_frame8.jpg: dane dodane.
# z_3_1_frame9.jpg: dane dodane.
# z_4_1_frame1.jpg: dane dodane.
# z_4_1_frame10.jpg: dane dodane.
# z_4_1_frame2.jpg: dane dodane.
# z_4_1_frame3.jpg: dane dodane.
# z_4_1_frame4.jpg: dane dodane.
# z_4_1_frame5.jpg: dane dodane.
# z_4_1_frame6.jpg: dane dodane.
# z_4_1_frame7.jpg: dane dodane.
# z_4_1_frame8.jpg: dane dodane.
# z_4_1_frame9.jpg: dane dodane.
# z_5_1_frame1.jpg: dane dodane.
# z_5_1_frame10.jpg: NIE wykryto dłoni
# z_5_1_frame2.jpg: dane dodane.
# z_5_1_frame3.jpg: dane dodane.
# z_5_1_frame4.jpg: dane dodane.
# z_5_1_frame5.jpg: dane dodane.
# z_5_1_frame6.jpg: dane dodane.
# z_5_1_frame7.jpg: dane dodane.
# z_5_1_frame8.jpg: NIE wykryto dłoni
# z_5_1_frame9.jpg: NIE wykryto dłoni
# z_6_1_frame1.jpg: dane dodane.
# z_6_1_frame10.jpg: dane dodane.
# z_6_1_frame2.jpg: dane dodane.
# z_6_1_frame3.jpg: dane dodane.
# z_6_1_frame4.jpg: dane dodane.
# z_6_1_frame5.jpg: dane dodane.
# z_6_1_frame6.jpg: dane dodane.
# z_6_1_frame7.jpg: dane dodane.
# z_6_1_frame8.jpg: dane dodane.
# z_6_1_frame9.jpg: dane dodane.
# z_7_1_frame1.jpg: dane dodane.
# z_7_1_frame10.jpg: dane dodane.
# z_7_1_frame2.jpg: dane dodane.
# z_7_1_frame3.jpg: dane dodane.
# z_7_1_frame4.jpg: dane dodane.
# z_7_1_frame5.jpg: dane dodane.
# z_7_1_frame6.jpg: dane dodane.
# z_7_1_frame7.jpg: dane dodane.
# z_7_1_frame8.jpg: NIE wykryto dłoni
# z_7_1_frame9.jpg: dane dodane.
# z_8_1_frame1.jpg: dane dodane.
# z_8_1_frame10.jpg: dane dodane.
# z_8_1_frame2.jpg: dane dodane.
# z_8_1_frame3.jpg: dane dodane.
# z_8_1_frame4.jpg: dane dodane.
# z_8_1_frame5.jpg: dane dodane.
# z_8_1_frame6.jpg: dane dodane.
# z_8_1_frame7.jpg: dane dodane.
# z_8_1_frame8.jpg: dane dodane.
# z_8_1_frame9.jpg: dane dodane.
# z_9_1_frame1.jpg: dane dodane.
# z_9_1_frame10.jpg: dane dodane.
# z_9_1_frame2.jpg: dane dodane.
# z_9_1_frame3.jpg: dane dodane.
# z_9_1_frame4.jpg: dane dodane.
# z_9_1_frame5.jpg: dane dodane.
# z_9_1_frame6.jpg: NIE wykryto dłoni
# z_9_1_frame7.jpg: dane dodane.
# z_9_1_frame8.jpg: dane dodane.
# z_9_1_frame9.jpg: dane dodane.
